# %% [markdown]
# # <font color='Green'>Future projection of cryptocurrencies with prophet library</font>
#
# ### Celso H A Diniz

# %%
from IPython.display import Image
Image(filename='img/dollar.png')

# %% [markdown]
# # <font color='Red'>Warning</font>
# #### For testing and study purposes only, it is not intended as a guide for future investments.
#
# #### Investments in crypto assets are very high risk.
#
# #### Don't buy cryptocurrencies or assets if you don't have prior knowledge or because you've heard of high earnings. The gain is proportional to the risk.
#
# #### This is not indicative, but if you happen to be interested in the subject and are willing to take risks, only invest what you are willing to lose, as there is a chance of losing the investment altogether.

# %% [markdown]
# ### Whats is Prophet: Automatic Forecasting Procedure
#
# "Tool for producing high quality forecasts for time series data that has multiple seasonality with linear or non-linear growth."
#
#
# Prophet is a procedure for forecasting time series data based on an additive model where non-linear trends are fit with yearly, weekly, and daily seasonality, plus holiday effects. It works best with time series that have strong seasonal effects and several seasons of historical data. Prophet is robust to missing data and shifts in the trend, and typically handles outliers well.
#
# https://facebook.github.io/prophet/
#
# https://github.com/facebook/prophet

# %%
### Install: 
#pip install plotly==4.14.3
# or conda
#conda install -c plotly plotly=4.14.3

# %%
# install: Anaconda
#conda install -c conda-forge fbprophet
#conda install pandas

#install: If you need packages that are available to pip but not conda, then install pip, and then use pip to install those packages:
#conda install pip
#pip install pandas

# %%
#pip install fbprophet --no-cache

# %%
#pip install pystan --no-cache

# %%
import pandas as pd
from prophet import Prophet # install: conda install -c conda-forge fbprophet
import pandas_datareader as web
from fbprophet.plot import plot
from matplotlib import pyplot as plt
from matplotlib.dates import MonthLocator, num2date
from matplotlib.ticker import FuncFormatter
from IPython.display import Image

# %% [markdown]
# # Dogecoin(DOGE):
# https://coinmarketcap.com/currencies/dogecoin/

# %%
Image(filename='img/dogekill.jpeg')

# %%
df = web.DataReader('DOGE-USD', data_source='yahoo', start='2019-12-01', end='2021-06-10') 
df.head()

# %% [markdown]
# ### The Facebook Prophet model only works with data that contains a string time-series format in a column called <font color='red'>"ds"</font> and continuous values in a column called <font color='red'>"y"</font>. So we need to create the data accordingly:

# %%
df = df.reset_index(drop=False)
#The Facebook Prophet model only works with data that contains a string time-series format in a column called “ds” and continuous values in a column called “y”. So we need to create the data accordingly:
doge = df[["Date", "Close"]]
doge.columns = ["ds", "y"]
doge.head()

# %%
#Now let’s fit the data into our model:
m = Prophet()
m.fit(doge)

# %%
future = m.make_future_dataframe(periods=30) #periods = days
print(future)

# %%
forecast = m.predict(future)
forecast[["ds", "yhat", "yhat_lower", "yhat_upper"]].tail(200)

# %%
from prophet.plot import plot_plotly, plot_components_plotly
plot_plotly(m, forecast)

# %%
fig1 = m.plot(forecast)

# %%
fig2 = m.plot_components(forecast)

# %%
plot_components_plotly(m, forecast)

# %% [markdown]
# # Cardano(ADA):
# https://coinmarketcap.com/currencies/cardano/

# %%
Image(filename='img/cardano.jpg')

# %%
df = web.DataReader('ADA-USD', data_source='yahoo', start='2020-12-01', end='2021-06-08') 
df.head()

# %% [markdown]
# The Facebook Prophet model only works with data that contains a string time-series format in a column called <font color='red'>"ds"</font> and continuous values in a column called <font color='red'>"y"</font>. So we need to create the data accordingly:

# %%
df = df.reset_index(drop=False)
#The Facebook Prophet model only works with data that contains a string time-series format in a column called “ds” and continuous values in a column called “y”. So we need to create the data accordingly:
ada = df[["Date", "Close"]]
ada.columns = ["ds", "y"]
ada.head()

# %%
#Now let’s fit the data into our model:
m = Prophet()
m.fit(ada);

# %%
future = m.make_future_dataframe(periods=365)
print(future)

# %%
forecast = m.predict(future)
forecast[["ds", "yhat", "yhat_lower", "yhat_upper"]].tail(200)

# %%
from prophet.plot import plot_plotly, plot_components_plotly
plot_plotly(m, forecast)

# %%
fig1 = m.plot(forecast)

# %%
fig2 = m.plot_components(forecast)

# %%
plot_components_plotly(m, forecast)

# %% [markdown]
# # Bitcoin(BTC):
# https://coinmarketcap.com/currencies/bitcoin/

# %%
Image(filename='img/Bitcoin-logo.png')

# %%
df = web.DataReader('BTC-USD', data_source='yahoo', start='2013-12-01', end='2021-06-08') 
df.head()

# %% [markdown]
# The Facebook Prophet model only works with data that contains a string time-series format in a column called <font color='red'>"ds"</font> and continuous values in a column called <font color='red'>"y"</font>. So we need to create the data accordingly:

# %%
df = df.reset_index(drop=False)
#The Facebook Prophet model only works with data that contains a string time-series format in a column called “ds” and continuous values in a column called “y”. So we need to create the data accordingly:
btc = df[["Date", "Close"]]
btc.columns = ["ds", "y"]
btc.head()

# %%
#Now let’s fit the data into our model:
m = Prophet()
m.fit(btc);

# %%
future = m.make_future_dataframe(periods=365)
print(future)

# %%
forecast = m.predict(future)
forecast[["ds", "yhat", "yhat_lower", "yhat_upper"]].tail(200)

# %%
from prophet.plot import plot_plotly, plot_components_plotly
plot_plotly(m, forecast)

# %%
fig1 = m.plot(forecast)

# %%
fig2 = m.plot_components(forecast)

# %%
plot_components_plotly(m, forecast)

# %% [markdown]
# # Links:
# https://facebook.github.io/prophet/
#
# https://medium.com/plotly/plotly-py-4-0-is-here-offline-only-express-first-displayable-anywhere-fc444e5659ee
#
# https://plotly.com/python/getting-started/#jupyterlab-support
#
# https://dash.plotly.com/installation
#
# https://dash.plotly.com
#
#
# https://thecleverprogrammer.com/2020/11/15/machine-learning-projects/
